# %% [markdown]
# # Task 1: SIFT

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = 'your_image.jpeg' # Replace with your image path
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Initialize SIFT detector
sift = cv2.SIFT_create()

# Detect keypoints and compute descriptors
keypoints, descriptors = sift.detectAndCompute(gray, None)

# Draw keypoints on the original image
img_with_keypoints = cv2.drawKeypoints(
 img, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS
)

# Display the result
plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(img_with_keypoints, cv2.COLOR_BGR2RGB))
plt.title('SIFT Keypoints')
plt.axis('off')
plt.show()

# %% [markdown]
# # Task 2: HOG

# %%
import cv2
import matplotlib.pyplot as plt
from skimage.feature import hog
from skimage import exposure

# Load the image
image_path = 'your_image.jpeg' # Replace with your image path
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Compute HOG features and visualization
features, hog_image = hog(
 gray,
 orientations=9,
 pixels_per_cell=(8, 8),
 cells_per_block=(2, 2),
 block_norm='L2-Hys',
 visualize=True,
 transform_sqrt=True
)

# Enhance the HOG image for better visualization
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

# Display the original and HOG image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.imshow(gray, cmap='gray')
ax1.set_title('Original Image')
ax1.axis('off')
ax2.imshow(hog_image_rescaled, cmap='gray')
ax2.set_title('HOG Visualization')
ax2.axis('off')

plt.show()

# %% [markdown]
# # Task 3: Surf

# %%
# !pip install opencv-python
# !pip install opencv-contrib-python

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image_path = 'your_image.jpeg' # Replace with your image path
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Initialize SURF detector
#surf = cv2.xfeatures2d.SURF_create(hessianThreshold=400)

# Initialize ORB detector
orb = cv2.ORB_create()

# Detect keypoints and compute descriptors
keypoints, descriptors = orb.detectAndCompute(gray, None)

# Draw keypoints
img_with_keypoints = cv2.drawKeypoints(
 img, keypoints, None, (255, 0, 0),
flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS
)
# Display the image
plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(img_with_keypoints, cv2.COLOR_BGR2RGB))
plt.title('ORB Keypoints')
plt.axis('off')
plt.show()

# %% [markdown]
# # Task 4: Reflection

# %% [markdown]
# 1. I was not able to run Task 3 using SURF after trying to reinstall `opencv-python` and `opencv-contrib-python` with other versions. Instead, I used an alternative feature descriptor called ORB.
#
# 2. Both SIFT and HOG have areas of high efficiency in object recognition. The former recognizes objects even when they are scaled and rotated like identifying a logo on an image. The latter can detect objects with well-defined shapes or textures like detecting vehicles and traffic signs. Individually, SIFT excels in finding matching features between images, making it suited for image stitching or panoramas while HOG captures the distribution of edge orientations which is widely used in pedestrian detection systems. Lastly, ORB--known for speed, efficiency, and low computational requirements--is suitable for video analytics and robotics, as well as augmented reality application on smartphones.
